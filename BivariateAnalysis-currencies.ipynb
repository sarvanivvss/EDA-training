# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


#plt.matshow(dataframe.corr())
#plt.show()

# %%
df = pd.read_csv('/content/currencies.csv')
df

# %%
df.columns
# Out:
# Index(['Currency', 'Chinese Yuan', 'Euro', 'Japanese Yen',
#        'U.K. Pound Sterling', 'U.S. Dollar', 'Algerian Dinar',
#        'Australian Dollar', 'Bahrain Dinar', 'Botswana Pula', 'Brazilian Real',
#        'Brunei Dollar', 'Canadian Dollar', 'Chilean Peso', 'Colombian Peso',
#        'Czech Koruna', 'Danish Krone', 'Hungarian Forint', 'Icelandic Krona',
#        'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial',
#        'Israeli New Sheqel', 'Kazakhstani Tenge', 'Korean Won',
#        'Kuwaiti Dinar', 'Libyan Dinar', 'Malaysian Ringgit', 'Mauritian Rupee',
#        'Mexican Peso', 'Nepalese Rupee', 'New Zealand Dollar',
#        'Norwegian Krone', 'Rial Omani', 'Pakistani Rupee', 'Nuevo Sol',
#        'Philippine Peso', 'Polish Zloty', 'Qatar Riyal', 'Russian Ruble',
#        'Saudi Arabian Riyal', 'Singapore Dollar', 'South African Rand',
#        'Sri Lanka Rupee', 'Swedish Krona', 'Swiss Franc', 'Thai Baht',
# ...

# %%
currency=df.corr()
currency
# Out:
# <ipython-input-10-d23f0694b8aa>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   currency=df.corr()
#                             Chinese Yuan      Euro  Japanese Yen  \
# Chinese Yuan                    1.000000  0.151596      0.115165
# Euro                            0.151596  1.000000     -0.639716
# Japanese Yen                    0.115165 -0.639716      1.000000
# U.K. Pound Sterling             0.108695  0.531150     -0.933538
# U.S. Dollar                     0.291582 -0.210587      0.178899
# Algerian Dinar                  0.627593  0.221863     -0.237148
# Australian Dollar               0.077983  0.331588     -0.547589
# Bahrain Dinar                   0.291926 -0.209926      0.178684
# Botswana Pula                   0.366492  0.461294     -0.623155
# ...

# %%
correlation_value = df.corr()['Indian Rupee']
sorted_correlations = correlation_value.sort_values(ascending=True)
sorted_correlations
# Out:
# <ipython-input-30-032e65e05968>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_value = df.corr()['Indian Rupee']
# Swiss Franc                  -0.655866
# Tunisian Dinar               -0.618041
# Japanese Yen                 -0.264721
# Swedish Krona                -0.186991
# Trinidad And Tobago Dollar   -0.186861
# Kazakhstani Tenge            -0.074799
# Philippine Peso              -0.057445
# Brazilian Real               -0.056475
# Norwegian Krone              -0.019682
# Euro                          0.243851
# Danish Krone                  0.282445
# Chinese Yuan                  0.304050
# Canadian Dollar               0.304291
# U.K. Pound Sterling           0.314681
# New Zealand Dollar            0.444635
# Polish Zloty                  0.474792
# ...

# %%
#kot = df[df <= -0.9]

plt.figure(figsize=(12, 12))
plt.rc('legend', fontsize=12)
sns.heatmap(kot, annot=True, cmap="Reds")
plt.show()

# %%
correlation_matrix = currency.corr()

# Stack the correlation matrix to create a Series
correlation_series = correlation_matrix.stack()

# Find the index (column names) corresponding to the minimum correlation value
most_negative_corr_index = correlation_series.idxmin()

# Extract column names and correlation value
column1, column2 = most_negative_corr_index
most_negative_corr_value = correlation_series.loc[most_negative_corr_index]
f"The columns with the most negative correlation are '{column1}' and '{column2}' with a correlation value of {most_negative_corr_value}."
# Out:
# "The columns with the most negative correlation are 'Japanese Yen' and 'U.K. Pound Sterling' with a correlation value of -0.9798697698873596."
